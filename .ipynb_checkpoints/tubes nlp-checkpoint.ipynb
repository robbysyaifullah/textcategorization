# %%
from twitterscraper import query_tweets

# %%
# list_of_tweets = query_tweets("Presiden OR Jokowi OR Pemerintah OR Menteri", 100, poolsize=20)

# #Or save the retrieved tweets to file:
# file = open('output.txt','w')
# for tweet in query_tweets("Presiden OR Jokowi OR Pemerintah OR Menteri", 100):
#     file.write(str(tweet.text.encode('utf-8')) +',\n')
# file.close()
# Out:
# INFO: queries: ['Presiden OR Jokowi OR Pemerintah OR Menteri since:2006-03-21 until:2006-11-06', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2006-11-06 until:2007-06-25', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2007-06-25 until:2008-02-11', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2008-02-11 until:2008-09-29', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2008-09-29 until:2009-05-18', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2009-05-18 until:2010-01-04', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2010-01-04 until:2010-08-23', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2010-08-23 until:2011-04-11', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2011-04-11 until:2011-11-28', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2011-11-28 until:2012-07-16', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2012-07-16 until:2013-03-03', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2013-03-03 until:2013-10-20', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2013-10-20 until:2014-06-08', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2014-06-08 until:2015-01-25', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2015-01-25 until:2015-09-13', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2015-09-13 until:2016-05-01', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2016-05-01 until:2016-12-18', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2016-12-18 until:2017-08-06', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2017-08-06 until:2018-03-25', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2018-03-25 until:2018-11-11']
# INFO: Got 0 tweets (0 new).
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 77 tweets (17 new).
# INFO: Got 97 tweets (20 new).
# INFO: Got 117 tweets (20 new).
# INFO: Got 137 tweets (20 new).
# INFO: Got 157 tweets (20 new).
# INFO: Got 174 tweets (17 new).
# INFO: Got 189 tweets (15 new).
# INFO: Got 209 tweets (20 new).
# INFO: Got 229 tweets (20 new).
# INFO: Got 249 tweets (20 new).
# INFO: Got 269 tweets (20 new).
# INFO: Got 289 tweets (20 new).
# INFO: Got 309 tweets (20 new).
# INFO: Got 329 tweets (20 new).
# INFO: Got 349 tweets (20 new).
# INFO: Got 369 tweets (20 new).
# INFO: queries: ['Presiden OR Jokowi OR Pemerintah OR Menteri since:2006-03-21 until:2006-11-06', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2006-11-06 until:2007-06-25', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2007-06-25 until:2008-02-11', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2008-02-11 until:2008-09-29', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2008-09-29 until:2009-05-18', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2009-05-18 until:2010-01-04', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2010-01-04 until:2010-08-23', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2010-08-23 until:2011-04-11', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2011-04-11 until:2011-11-28', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2011-11-28 until:2012-07-16', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2012-07-16 until:2013-03-03', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2013-03-03 until:2013-10-20', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2013-10-20 until:2014-06-08', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2014-06-08 until:2015-01-25', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2015-01-25 until:2015-09-13', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2015-09-13 until:2016-05-01', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2016-05-01 until:2016-12-18', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2016-12-18 until:2017-08-06', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2017-08-06 until:2018-03-25', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2018-03-25 until:2018-11-11']
# INFO: Got 20 tweets (20 new).
# INFO: Got 20 tweets (0 new).
# INFO: Got 35 tweets (15 new).
# INFO: Got 55 tweets (20 new).
# INFO: Got 75 tweets (20 new).
# INFO: Got 95 tweets (20 new).
# INFO: Got 115 tweets (20 new).
# INFO: Got 135 tweets (20 new).
# INFO: Got 155 tweets (20 new).
# INFO: Got 175 tweets (20 new).
# INFO: Got 195 tweets (20 new).
# INFO: Got 212 tweets (17 new).
# INFO: Got 232 tweets (20 new).
# INFO: Got 252 tweets (20 new).
# INFO: Got 272 tweets (20 new).
# INFO: Got 292 tweets (20 new).
# INFO: Got 309 tweets (17 new).
# INFO: Got 329 tweets (20 new).
# INFO: Got 349 tweets (20 new).
# INFO: Got 369 tweets (20 new).
# WASHINGTON (Reuters) - Sen. Hillary Clinton, viewed last year as
# virtually unstoppable in her bid to become the U.S. Democratic
# presiden ...
# WASHINGTON (Reuters) - Sen. Hillary Clinton, viewed last year as
# virtually unstoppable in her bid to become the U.S. Democratic
# presiden ...
# WASHINGTON (Reuters) - Sen. Hillary Clinton, viewed last year as
# virtually unstoppable in her bid to become the U.S. Democratic
# presiden ...
# WASHINGTON (Reuters) - Sen. Hillary Clinton, viewed last year as
# virtually unstoppable in her bid to become the U.S. Democratic
# presiden ...
# WASHINGTON (Reuters) - Sen. Hillary Clinton, viewed last year as
# virtually unstoppable in her bid to become the U.S. Democratic
# presiden ...
 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2013-10-20 until:2014-06-08', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2014-06-08 until:2015-01-25', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2015-01-25 until:2015-09-13', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2015-09-13 until:2016-05-01', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2016-05-01 until:2016-12-18', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2016-12-18 until:2017-08-06', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2017-08-06 until:2018-03-25', 'Presiden OR Jokowi OR Pemerintah OR Menteri since:2018-03-25 until:2018-11-11']
# INFO: Got 0 tweets (0 new).
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 115 tweets (15 new).
# INFO: Got 135 tweets (20 new).
# INFO: Got 155 tweets (20 new).
# INFO: Got 172 tweets (17 new).
# INFO: Got 192 tweets (20 new).
# INFO: Got 209 tweets (17 new).
# INFO: Got 229 tweets (20 new).
# INFO: Got 249 tweets (20 new).
# INFO: Got 269 tweets (20 new).
# INFO: Got 289 tweets (20 new).
# INFO: Got 309 tweets (20 new).
# INFO: Got 329 tweets (20 new).
# INFO: Got 349 tweets (20 new).
# INFO: Got 369 tweets (20 new).

# %%
import codecs, json, csv
import pandas as pd

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
with codecs.open('dengantolong.json', 'r', 'utf-8') as f:
    tweets = json.load(f, encoding='utf-8')

list_tweets = [list(elem.values()) for elem in tweets]
list_columns = list(tweets[0].keys())
df = pd.DataFrame(list_tweets, columns=list_columns)

tweets[1]
# Out:
# {'fullname': 'SHOWNU.',
#  'html': '<p class="TweetTextSize js-tweet-text tweet-text" data-aria-label-part="0" lang="in">Telkomsel: ikeq_drono Terima kasih untuk  data yg diberikanTerkait keluhan tarif TM tidak sesuai, saya bantu cek kembali. <strong>Mohon</strong> ditunggu. T…</p>',
#  'id': '874415986270720000',
#  'likes': '0',
#  'replies': '0',
#  'retweets': '0',
#  'text': 'Telkomsel: ikeq_drono Terima kasih untuk  data yg diberikanTerkait keluhan tarif TM tidak sesuai, saya bantu cek kembali. Mohon ditunggu. T…',
#  'timestamp': '2017-06-12T23:59:51',
#  'url': '/SIRESHOWNU/status/874415986270720000',
#  'user': 'SIRESHOWNU'}

# %%
list_tweet = []
for i in range(len(tweets)):
    list_tweet.append([tweets[i]['user'],'1', tweets[i]['text']])
    
df = pd.DataFrame(list_tweet, columns=['name','class','text'])
# df.to_csv('dengantolong.csv')

# %%
import pandas as pd, csv
import string as string

import re

from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize


from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
twitters = pd.read_csv("twitter_training.csv")
X = twitters['text']

# %%
def removeURL(raw):
    cleanr = re.compile("http?:\/\/.*[\r\n]*")
    cleantext = re.sub(cleanr, '', raw)
    
    return cleantext

preprocess = []

for i in range(len(X)):
    preprocess.append(removeURL(X[i]))

X = preprocess

X[1]
# Out:
# '@jokowi OK, Kami jg bangga. Tolong olahraga lain jg di perhatikan, Bgmn nasib PSSI? pemerintah jgn byk intervensi yg hrsnya di bina'

# %%
def stemWord(w):
    words = word_tokenize(w)
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()

    sentence = ''
    for word in words:
        sentence += str(stemmer.stem(word)) + ' '
    return sentence
    
process = []
for i in range(len(X)):
    process.append(stemWord(X[i]))
    
X = process
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-1c8f2d665902> in <module>()
#      11 process = []
#      12 for i in range(len(X)):
# ---> 13     process.append(stemWord(X[i]))
#      14
#      15 X = process
#
# <ipython-input-59-1c8f2d665902> in stemWord(w)
#       6     sentence = ''
#       7     for word in words:
# ----> 8         sentence += str(stemmer.stem(word)) + ' '
#       9     return sentence
#      10
#
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\Sastrawi\Stemmer\CachedStemmer.py in stem(self, text)
#      18                 stems.append(self.cache.get(word))
#      19             else:
# ---> 20                 stem = self.delegatedStemmer.stem(word)
#      21                 self.cache.set(word, stem)
#      22                 stems.append(stem)
#
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\Sastrawi\Stemmer\Stemmer.py in stem(self, text)
#      25
#      26         for word in words:
# ---> 27             stems.append(self.stem_word(word))
#      28
#      29         return ' '.join(stems)
#
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\Sastrawi\Stemmer\Stemmer.py in stem_word(self, word)
#      34             return self.stem_plural_word(word)
#      35         else:
# ---> 36             return self.stem_singular_word(word)
#      37
#      38     def is_plural(self, word):
#
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\Sastrawi\Stemmer\Stemmer.py in stem_singular_word(self, word)
#      82         """Stem a singular word to its common stem form."""
#      83         context = Context(word, self.dictionary, self.visitor_provider)
# ---> 84         context.execute()
#      85
#      86         return context.result
#
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\Sastrawi\Stemmer\Context\Context.py in execute(self)
#      35
#      36         #step 1 - 5
# ---> 37         self.start_stemming_process()
#      38
#      39         #step 6
#
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\Sastrawi\Stemmer\Context\Context.py in start_stemming_process(self)
#      78
#      79         #step 4, 5
# ---> 80         self.remove_prefixes()
#      81         if self.dictionary.contains(self.current_word):
#      82             return
#
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\Sastrawi\Stemmer\Context\Context.py in remove_prefixes(self)
#      87     def remove_prefixes(self):
#      88         for i in range(3):
# ---> 89             self.accept_prefix_visitors(self.prefix_pisitors)
#      90             if self.dictionary.contains(self.current_word):
#      91                 return
#
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\Sastrawi\Stemmer\Context\Context.py in accept_prefix_visitors(self, visitors)
#     108         removalCount = len(self.removals)
#     109         for visitor in visitors:
# --> 110             self.accept(visitor)
#     111             if self.dictionary.contains(self.current_word):
#     112                 return self.current_word
#
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\Sastrawi\Stemmer\Context\Context.py in accept(self, visitor)
#      95
#      96     def accept(self, visitor):
# ---> 97         visitor.visit(self)
#      98
#      99     def accept_visitors(self, visitors):
#
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\Sastrawi\Stemmer\Context\Visitor\AbstractDisambiguatePrefixRule.py in visit(self, context)
#      13         for disambiguator in self.disambiguators:
#      14             result = disambiguator.disambiguate(context.current_word)
# ---> 15             if context.dictionary.contains(result):
#      16                 break
#      17
#
# KeyboardInterrupt:

# %%
X[26:29]
# Out:
# ['PLN TOLONG SIH KASIH PENJELASAN KENAPA LISTRIK MATI TRUS? SEHARI BISA 4X, ELEKTRONIK KAMI BS RUSAK BEGINI TRUS #PLNLAMPUNG#@JOKOWI',
#  'Assalamualaikum wr wb Bapak Presiden Yth @jokowi kabarnya Dr. Zakir Naik akan datang ke Indonesia. Tolong disiarkan di Tv Nasional ya Pak.',
#  '@TelkomCare pak @jokowi  n pak @Pak_JK  masyarakat Internet  sbnrnya sangat menyayangkan mahalnya tarif ini. mohon dengarkan suara kami.']

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vect = CountVectorizer()
count_vect.fit(X)
x = count_vect.transform(X)
y = twitters['class']

print(len(X), len(y))
# Out:
# 1157 1157

# %%
# Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
text_train, text_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
# Classifier

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import cross_val_score

# %%
log_regression = LogisticRegression()
log_regression.fit(x_train, y_train)

log_regression_pred = log_regression.predict(x_test)
print('F1 Score Logistic : ', f1_score(log_regression_pred, y_test))
print('Accuracy Score Logistic : ', accuracy_score(log_regression_pred, y_test))
print('Precision Score Logistic : ', precision_score(log_regression_pred, y_test))
print('Recall Score Logistic : ', recall_score(log_regression_pred, y_test))

scores = cross_val_score(log_regression, x, y, scoring='f1', cv=5)

print('Mean Logistic Regression: ', scores.mean())
print('Std Logistic Regression: ', scores.std())
# Out:
# F1 Score Logistic :  0.4810126582278481
# Accuracy Score Logistic :  0.7172413793103448
# Precision Score Logistic :  0.3838383838383838
# Recall Score Logistic :  0.6440677966101694
# Mean Logistic Regression:  0.44311919200396055
# Std Logistic Regression:  0.04201457465632797

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier()

tree.fit(x_train, y_train)

tree_pred = tree.predict(x_test)
print('F1 Score Logistic : ', f1_score(tree_pred, y_test))
print('Accuracy Score Logistic : ', accuracy_score(tree_pred, y_test))
print('Precision Score Logistic : ', precision_score(tree_pred, y_test))
print('Recall Score Logistic : ', recall_score(tree_pred, y_test))
# Out:
# F1 Score Logistic :  0.39361702127659576
# Accuracy Score Logistic :  0.6068965517241379
# Precision Score Logistic :  0.37373737373737376
# Recall Score Logistic :  0.4157303370786517

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

svc.fit(x_train, y_train)


svc_pred = svc.predict(x_test)

print('F1 Score Logistic : ', f1_score(svc_pred, y_test))
print('Accuracy Score Logistic : ', accuracy_score(svc_pred, y_test))
print('Precision Score Logistic : ', precision_score(svc_pred, y_test))
print('Recall Score Logistic : ', recall_score(svc_pred, y_test))
# Out:
# F1 Score Logistic :  0.0
# Accuracy Score Logistic :  0.6586206896551724
# Precision Score Logistic :  0.0
# Recall Score Logistic :  0.0
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neigh = KNeighborsClassifier(n_neighbors=3)

neigh.fit(x_train, y_train)

neigh_pred = neigh.predict(x_test)
print('F1 Score Logistic : ', f1_score(neigh_pred, y_test))
print('Accuracy Score Logistic : ', accuracy_score(neigh_pred, y_test))
print('Precision Score Logistic : ', precision_score(neigh_pred, y_test))
print('Recall Score Logistic : ', recall_score(neigh_pred, y_test))
# Out:
# F1 Score Logistic :  0.10619469026548672
# Accuracy Score Logistic :  0.6517241379310345
# Precision Score Logistic :  0.06060606060606061
# Recall Score Logistic :  0.42857142857142855

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()
gnb_pred = gnb.fit(x_train.toarray(), y_train.toarray()).predict(x_test)

print('F1 Score Logistic : ', f1_score(gnb_pred, y_test))
print('Accuracy Score Logistic : ', accuracy_score(gnb_pred, y_test))
print('Precision Score Logistic : ', precision_score(gnb_pred, y_test))
print('Recall Score Logistic : ', recall_score(gnb_pred, y_test))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-b737273bf3f6> in <module>()
#       1 gnb = GaussianNB()
# ----> 2 gnb_pred = gnb.fit(x_train.as_matrix(), y_train.as_matrix()).predict(x_test)
#       3
#       4 print('F1 Score Logistic : ', f1_score(gnb_pred, y_test))
#       5 print('Accuracy Score Logistic : ', accuracy_score(gnb_pred, y_test))
#
# c:\users\meh\appdata\local\programs\python\python36\lib\site-packages\scipy\sparse\base.py in __getattr__(self, attr)
#     684             return self.getnnz()
#     685         else:
# --> 686             raise AttributeError(attr + " not found")
#     687
#     688     def transpose(self, axes=None, copy=False):
#
# AttributeError: as_matrix not found
